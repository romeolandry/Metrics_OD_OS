# %%
import torch.onnx
import io
import numpy as np
import torchvision.models as models

# %%
model_path = 'model_OT_e2e_faster_rcnn_R_101_FPN_1x_weight.pth'

# %%
# Create the right input shape (e.g. for an image)
dummy_input = torch.randn(3, 245, 245)
#model = models.alexnet(pretrained=True)
model = torch.load(model_path)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /home/kamgo/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# 21.1%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-3ff6dd2931f8> in <module>
#       1 # Create the right input shape (e.g. for an image)
#       2 dummy_input = torch.randn(3, 245, 245)
# ----> 3 model = models.alexnet(pretrained=True)
#       4 model = torch.load(model_path)
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torchvision/models/alexnet.py in alexnet(pretrained, **kwargs)
#      56     model = AlexNet(**kwargs)
#      57     if pretrained:
# ---> 58         model.load_state_dict(model_zoo.load_url(model_urls['alexnet']))
#      59     return model
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torch/hub.py in load_state_dict_from_url(url, model_dir, map_location, progress, check_hash)
#     493         sys.stderr.write('Downloading: "{}" to {}\n'.format(url, cached_file))
#     494         hash_prefix = HASH_REGEX.search(filename).group(1) if check_hash else None
# --> 495         download_url_to_file(url, cached_file, hash_prefix, progress=progress)
#     496
#     497     # Note: extractall() defaults to overwrite file if exists. No need to clean up beforehand.
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torch/hub.py in download_url_to_file(url, dst, hash_prefix, progress)
#     414                   unit='B', unit_scale=True, unit_divisor=1024) as pbar:
#     415             while True:
# --> 416                 buffer = u.read(8192)
#     417                 if len(buffer) == 0:
#     418                     break
#
# /usr/lib/python3.6/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# /usr/lib/python3.6/http/client.py in readinto(self, b)
#     501         # connection, and the user is reading more bytes than will be provided
#     502         # (for example, reading in 1k chunks)
# --> 503         n = self.fp.readinto(b)
#     504         if not n and b:
#     505             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
torch.onnx.export(model, dummy_input, "onnx_model_name.onnx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f5b1a3350dc2> in <module>
# ----> 1 torch.onnx.export(model, dummy_input, "onnx_model_name.onnx")
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torch/onnx/__init__.py in export(model, args, f, export_params, verbose, training, input_names, output_names, aten, export_raw_ir, operator_export_type, opset_version, _retain_param_name, do_constant_folding, example_outputs, strip_doc_string, dynamic_axes, keep_initializers_as_inputs, custom_opsets, enable_onnx_checker, use_external_data_format)
#     166                         do_constant_folding, example_outputs,
#     167                         strip_doc_string, dynamic_axes, keep_initializers_as_inputs,
# --> 168                         custom_opsets, enable_onnx_checker, use_external_data_format)
#     169
#     170
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torch/onnx/utils.py in export(model, args, f, export_params, verbose, training, input_names, output_names, aten, export_raw_ir, operator_export_type, opset_version, _retain_param_name, do_constant_folding, example_outputs, strip_doc_string, dynamic_axes, keep_initializers_as_inputs, custom_opsets, enable_onnx_checker, use_external_data_format)
#      67             dynamic_axes=dynamic_axes, keep_initializers_as_inputs=keep_initializers_as_inputs,
#      68             custom_opsets=custom_opsets, enable_onnx_checker=enable_onnx_checker,
# ---> 69             use_external_data_format=use_external_data_format)
#      70
#      71
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torch/onnx/utils.py in _export(model, args, f, export_params, verbose, training, input_names, output_names, operator_export_type, export_type, example_outputs, propagate, opset_version, _retain_param_name, do_constant_folding, strip_doc_string, dynamic_axes, keep_initializers_as_inputs, fixed_batch_size, custom_opsets, add_node_names, enable_onnx_checker, use_external_data_format)
#     486                                                         example_outputs, propagate,
#     487                                                         _retain_param_name, val_do_constant_folding,
# --> 488                                                         fixed_batch_size=fixed_batch_size)
#     489
#     490         # TODO: Don't allocate a in-memory string for the protobuf
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torch/onnx/utils.py in _model_to_graph(model, args, verbose, training, input_names, output_names, operator_export_type, example_outputs, propagate, _retain_param_name, do_constant_folding, _disable_torch_constant_prop, fixed_batch_size)
#     332             model.graph, tuple(in_vars), False, propagate)
#     333     else:
# --> 334         graph, torch_out = _trace_and_get_graph_from_model(model, args, training)
#     335         state_dict = _unique_state_dict(model)
#     336         params = list(state_dict.values())
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torch/onnx/utils.py in _trace_and_get_graph_from_model(model, args, training)
#     280     # A basic sanity check: make sure the state_dict keys are the same
#     281     # before and after running the model.  Fail fast!
# --> 282     orig_state_dict_keys = _unique_state_dict(model).keys()
#     283
#     284     # By default, training=False, which is good because running a model in
#
# ~/.virtualenvs/evaluation/lib/python3.6/site-packages/torch/jit/__init__.py in _unique_state_dict(module, keep_vars)
#     284     # id(v) doesn't work with it. So we always get the Parameter or Buffer
#     285     # as values, and deduplicate the params using Parameters and Buffers
# --> 286     state_dict = module.state_dict(keep_vars=True)
#     287     filtered_dict = type(state_dict)()
#     288     seen_ids = set()
#
# AttributeError: 'str' object has no attribute 'state_dict'
